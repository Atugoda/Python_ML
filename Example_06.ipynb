# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report
import seaborn as sns

url = "http://archive.ics.uci.edu/ml/machine-learning-database/iris/iris.data"

columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
df = pd.read_csv(url,names=columns)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 14
#      11 url = "http://archive.ics.uci.edu/ml/machine-learning-database/iris/iris.data"
#      13 columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
# ---> 14 df = pd.read_csv(url,names=columns)
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns

# Correct URL for the Iris dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Define the column names
columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# Load the dataset
df = pd.read_csv(url, names=columns)

# Display the first few rows to verify
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns

# Correct URL for the Iris dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Define the column names
columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# Load the dataset
df = pd.read_csv(url, names=columns)

df = df[df['species'].isin(['Iris-setosa','iris-versicolor'])]

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns

# Correct URL for the Iris dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Define the column names
columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# Load the dataset
df = pd.read_csv(url, names=columns)

# Filter for only two species: 'Iris-setosa' and 'Iris-versicolor'
df = df[df['species'].isin(['Iris-setosa', 'Iris-versicolor'])]

# Map the species to binary values: 0 for 'Iris-setosa' and 1 for 'Iris-versicolor'
df['species'] = df['species'].map({'Iris-setosa': 0, 'Iris-versicolor': 1})

# Define a function to remove outliers
# Solving the outliers
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)  # First quartile (25th percentile)
    Q3 = df[column].quantile(0.75)  # Third quartile (75th percentile)
    IQR = Q3 - Q1  # Interquartile Range
    lower_bound = Q1 - 1.5 * IQR  # Lower whisker
    upper_bound = Q3 + 1.5 * IQR  # Upper whisker
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Example of using the remove_outliers function
for col in ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']:
    df = remove_outliers(df, col)

# # Display the cleaned dataset
# print(df.head())

df.loc[5:10, 'sepal_length'] = np.nan
print ("Missing values before handling:\n",df.isnull().sum())

imputer = SimpleImputer(strategy='mean')
df[['sepal_length', 'sepal_width','petal_length', 'petal_width']] = imputer.flt_transform(df[['sepal_length', 'sepal_width','petal_length', 'petal_width']])
print("Missing values after handling:\n",df.isnull().sum())

scaler = StandardScaler()
df[['sepal_length', 'sepal_width','petal_length', 'petal_width']] = scale.flt_transform(df[['sepal_length', 'sepal_width','petal_length', 'petal_width']])                                                                                     )
# Out:
#   Cell In[6], line 72
#     df[['sepal_length', 'sepal_width','petal_length', 'petal_width']] = scale.flt_transform(df[['sepal_length', 'sepal_width','petal_length', 'petal_width']])                                                                                     )
#                                                                                                                                                                                                                                                    ^
# SyntaxError: unmatched ')'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns

# Correct URL for the Iris dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Define the column names
columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# Load the dataset
df = pd.read_csv(url, names=columns)

# Filter for only two species: 'Iris-setosa' and 'Iris-versicolor'
df = df[df['species'].isin(['Iris-setosa', 'Iris-versicolor'])]

# Map the species to binary values: 0 for 'Iris-setosa' and 1 for 'Iris-versicolor'
df['species'] = df['species'].map({'Iris-setosa': 0, 'Iris-versicolor': 1})

# Define a function to remove outliers
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)  # First quartile (25th percentile)
    Q3 = df[column].quantile(0.75)  # Third quartile (75th percentile)
    IQR = Q3 - Q1  # Interquartile Range
    lower_bound = Q1 - 1.5 * IQR  # Lower whisker
    upper_bound = Q3 + 1.5 * IQR  # Upper whisker
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Remove outliers from all numeric columns
for col in ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']:
    df = remove_outliers(df, col)

# Introduce missing values for demonstration
df.loc[5:10, 'sepal_length'] = np.nan
print("Missing values before handling:\n", df.isnull().sum())

# Handle missing values using SimpleImputer
imputer = SimpleImputer(strategy='mean')
df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']] = imputer.fit_transform(
    df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
)
print("Missing values after handling:\n", df.isnull().sum())

# Scale the data using StandardScaler
scaler = StandardScaler()
df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']] = scaler.fit_transform(
    df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
)

# Split the data into features and target
x = df.drop('species', axis=1)
y = df['species']

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, test_size=0.2, random_state=42)

# Logistic Regression model
model = LogisticRegression()
model.fit(x_train, y_train)

# Predictions
y_pred = model.predict(x_test)

# Model Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy * 100:.2f}%")

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion matrix:")
print(conf_matrix)

# Classification Report
class_report = classification_report(y_test, y_pred, target_names=['Iris-setosa', 'Iris-versicolor'])
print("\nClassification Report:")
print(class_report)

# Plot Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='coolwarm', xticklabels=['setosa', 'versicolor'], yticklabels=['setosa', 'versicolor'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Missing values before handling:
#  sepal_length    6
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
# Missing values after handling:
#  sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
# Model Accuracy: 100.00%
#
# Confusion matrix:
# [[10  0]
#  [ 0 10]]
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00        10
#
#        accuracy                           1.00        20
#       macro avg       1.00      1.00      1.00        20
#    weighted avg       1.00      1.00      1.00        20
